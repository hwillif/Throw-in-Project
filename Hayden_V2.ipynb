# %% [markdown]
# # Group 1 Throw-In Project

# %%
 # %pip install tqdm
 # %pip install statsbombpy
# Out:
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
#   WARNING: The script tqdm is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed tqdm-4.67.1
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting statsbombpy
#   Downloading statsbombpy-1.16.0-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (from statsbombpy) (2.3.1)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from statsbombpy) (2.32.4)
# Collecting requests-cache (from statsbombpy)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting inflect (from statsbombpy)
#   Downloading inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.12/site-packages (from statsbombpy) (1.5.1)
# Collecting more_itertools>=8.5.0 (from inflect->statsbombpy)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting typeguard>=4.0.1 (from inflect->statsbombpy)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: typing_extensions>=4.14.0 in /home/codespace/.local/lib/python3.12/site-packages (from typeguard>=4.0.1->inflect->statsbombpy) (4.14.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->statsbombpy) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->statsbombpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->statsbombpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->statsbombpy) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->statsbombpy) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->statsbombpy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->statsbombpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->statsbombpy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->statsbombpy) (2025.7.9)
# Requirement already satisfied: attrs>=21.2 in /home/codespace/.local/lib/python3.12/site-packages (from requests-cache->statsbombpy) (25.3.0)
# Collecting cattrs>=22.2 (from requests-cache->statsbombpy)
#   Downloading cattrs-25.2.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests-cache->statsbombpy) (4.3.8)
# Collecting url-normalize>=1.4 (from requests-cache->statsbombpy)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Downloading statsbombpy-1.16.0-py3-none-any.whl (16 kB)
# Downloading inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Downloading cattrs-25.2.0-py3-none-any.whl (70 kB)
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, typeguard, more_itertools, cattrs, requests-cache, inflect, statsbombpy
#   WARNING: The script url-normalize is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [statsbombpy] [cattrs]
# Successfully installed cattrs-25.2.0 inflect-7.5.0 more_itertools-10.8.0 requests-cache-1.2.1 statsbombpy-1.16.0 typeguard-4.4.4 url-normalize-2.2.1
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from statsbombpy import sb

from typing import Optional, Iterable
from statsbombpy import sb
from tqdm.auto import tqdm

# %% [markdown]
# ### Import Womans Data

# %%
# 2020-21 Womens Super League (Prem for Females)

WomenSL = sb.matches(competition_id=37, season_id=90)
# Out:
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
# Clean WomenSL
WomenSL_Clean = WomenSL[['match_id', 'match_date', 'competition', 'season', 'home_team', 'away_team', 'competition_stage']]
WomenSL_Clean.head()
# Out:
#    match_id  match_date  ...                away_team competition_stage
# 0   3775648  2021-02-28  ...              Arsenal WFC    Regular Season
# 1   3775609  2021-04-28  ...      West Ham United LFC    Regular Season
# 2   3775633  2021-02-06  ...  Tottenham Hotspur Women    Regular Season
# 3   3775570  2021-03-28  ...              Everton LFC    Regular Season
# 4   3775581  2021-03-28  ...              Aston Villa    Regular Season
#
# [5 rows x 7 columns]

# %%
# Function for Matches Left Join Events
## Looking though all the events and only keeping the ones that occured in matches present in WomenSL
def build_events_dataset(
    matches_df: pd.DataFrame,
    match_id_col: str = "match_id",
    save_csv: Optional[str] = None,
    keep_columns: Optional[Iterable[str]] = None,
    add_meta: bool = True,
    ) -> pd.DataFrame:

# Fetch events for all match_ids in `matches_df`, concatenate into one DataFrame,
# and (optionally) merge key match metadata columns.

# Parameters
# ----------
# matches_df : DataFrame containing at least `match_id`
# match_id_col : name of the match id column
# save_parquet : path to save a Parquet file (recommended)
# save_csv : path to save a CSV file
# keep_columns : iterable of event columns to keep (None = keep all)
# add_meta : merge match metadata columns (season, teams, date, week, competition)

# Returns
# -------
# DataFrame of all events with `match_id` and optional metadata.

    if match_id_col not in matches_df.columns:
        raise KeyError(f"`{match_id_col}` not in matches_df columns")


    meta_cols = [
    match_id_col,
    "season", "season_id", "season_name",
    "competition", "competition_id", "competition_name",
    "match_date", "match_week",
    "home_team", "away_team"
    ]
    meta = matches_df[[c for c in meta_cols if c in matches_df.columns]].drop_duplicates()

    all_frames = []
    failures = []

    mids = pd.unique(matches_df[match_id_col].astype("int64"))
    for mid in tqdm(mids, desc="Fetching events"):
        try:
            ev = sb.events(match_id=int(mid))
            ev[match_id_col] = int(mid)
            all_frames.append(ev)
        except Exception as e:
            failures.append((int(mid), str(e)))

    if not all_frames:
        raise RuntimeError("No events were loaded. Check your match_ids or environment.")

    events = pd.concat(all_frames, ignore_index=True)


    if keep_columns is not None:
        keep = list(set(keep_columns) | {match_id_col})
        events = events[[c for c in keep if c in events.columns]]


    if add_meta and not meta.empty:
        events = events.merge(meta, on=match_id_col, how="left")


    if save_csv:
        events.to_csv(save_csv, index=False)
        print(f"Saved events: {len(events):,} rows → {save_csv}")

    if failures:
        print(f"\n Skipped {len(failures)} matches due to errors (showing first 5):")
    for mid, msg in failures[:5]:
        print(f" match_id={mid}: {msg}")

    return events



events_df = build_events_dataset(
WomenSL_Clean,
keep_columns=None,
add_meta=True
)
# Out:
# Fetching events:   0%|          | 0/131 [00:00<?, ?it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   1%|          | 1/131 [00:00<00:17,  7.51it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   2%|▏         | 2/131 [00:00<00:15,  8.27it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   2%|▏         | 3/131 [00:00<00:14,  8.66it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   3%|▎         | 4/131 [00:00<00:14,  8.68it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   4%|▍         | 5/131 [00:00<00:14,  8.93it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   5%|▍         | 6/131 [00:00<00:13,  9.16it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   5%|▌         | 7/131 [00:00<00:13,  9.33it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   6%|▌         | 8/131 [00:00<00:13,  9.36it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   7%|▋         | 9/131 [00:00<00:13,  9.25it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   8%|▊         | 10/131 [00:01<00:13,  9.22it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   8%|▊         | 11/131 [00:01<00:12,  9.24it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  10%|▉         | 13/131 [00:01<00:12,  9.64it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  11%|█         | 14/131 [00:01<00:12,  9.38it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  11%|█▏        | 15/131 [00:01<00:12,  9.52it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  12%|█▏        | 16/131 [00:01<00:12,  9.48it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  13%|█▎        | 17/131 [00:01<00:12,  9.31it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  14%|█▎        | 18/131 [00:01<00:11,  9.47it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  15%|█▍        | 19/131 [00:02<00:12,  9.32it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  15%|█▌        | 20/131 [00:02<00:11,  9.50it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  16%|█▌        | 21/131 [00:02<00:11,  9.54it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  17%|█▋        | 22/131 [00:02<00:11,  9.63it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  18%|█▊        | 24/131 [00:02<00:10,  9.83it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  19%|█▉        | 25/131 [00:02<00:10,  9.79it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  20%|█▉        | 26/131 [00:02<00:10,  9.62it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  21%|██        | 27/131 [00:02<00:11,  9.45it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  21%|██▏       | 28/131 [00:03<00:11,  9.16it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  22%|██▏       | 29/131 [00:03<00:11,  9.20it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  23%|██▎       | 30/131 [00:03<00:10,  9.35it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  24%|██▎       | 31/131 [00:03<00:10,  9.44it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  24%|██▍       | 32/131 [00:03<00:10,  9.48it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  25%|██▌       | 33/131 [00:03<00:10,  9.40it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  26%|██▌       | 34/131 [00:03<00:10,  9.35it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  27%|██▋       | 35/131 [00:03<00:10,  9.26it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  27%|██▋       | 36/131 [00:03<00:10,  9.29it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  29%|██▉       | 38/131 [00:04<00:09,  9.69it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  30%|██▉       | 39/131 [00:04<00:09,  9.48it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  31%|███       | 40/131 [00:04<00:09,  9.22it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  31%|███▏      | 41/131 [00:04<00:09,  9.11it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  32%|███▏      | 42/131 [00:04<00:09,  9.24it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  33%|███▎      | 43/131 [00:04<00:09,  9.12it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  34%|███▎      | 44/131 [00:06<00:46,  1.87it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  34%|███▍      | 45/131 [00:06<00:35,  2.44it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  35%|███▌      | 46/131 [00:06<00:27,  3.10it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  36%|███▌      | 47/131 [00:06<00:21,  3.87it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  37%|███▋      | 48/131 [00:06<00:17,  4.68it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  37%|███▋      | 49/131 [00:06<00:14,  5.54it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  38%|███▊      | 50/131 [00:06<00:12,  6.30it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  39%|███▉      | 51/131 [00:06<00:11,  6.89it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  40%|███▉      | 52/131 [00:07<00:10,  7.30it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  40%|████      | 53/131 [00:07<00:10,  7.74it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  41%|████      | 54/131 [00:07<00:09,  7.97it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  42%|████▏     | 55/131 [00:07<00:09,  8.12it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  44%|████▎     | 57/131 [00:07<00:08,  8.77it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  44%|████▍     | 58/131 [00:07<00:08,  8.87it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  45%|████▌     | 59/131 [00:07<00:07,  9.06it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  46%|████▌     | 60/131 [00:07<00:07,  9.09it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  47%|████▋     | 61/131 [00:08<00:07,  8.84it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  47%|████▋     | 62/131 [00:08<00:07,  8.88it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  48%|████▊     | 63/131 [00:08<00:07,  9.11it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  49%|████▉     | 64/131 [00:08<00:07,  8.94it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  50%|████▉     | 65/131 [00:08<00:07,  9.16it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  50%|█████     | 66/131 [00:08<00:07,  9.09it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  51%|█████     | 67/131 [00:08<00:07,  9.13it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  52%|█████▏    | 68/131 [00:08<00:06,  9.32it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  53%|█████▎    | 69/131 [00:08<00:06,  9.29it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  53%|█████▎    | 70/131 [00:09<00:06,  9.39it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  54%|█████▍    | 71/131 [00:09<00:06,  9.52it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  55%|█████▍    | 72/131 [00:09<00:06,  9.45it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  56%|█████▌    | 73/131 [00:09<00:06,  9.41it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  56%|█████▋    | 74/131 [00:09<00:06,  9.23it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  57%|█████▋    | 75/131 [00:09<00:06,  8.85it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  58%|█████▊    | 76/131 [00:09<00:06,  8.93it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  59%|█████▉    | 77/131 [00:09<00:06,  8.95it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  60%|█████▉    | 78/131 [00:09<00:05,  9.10it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  60%|██████    | 79/131 [00:10<00:05,  9.08it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  61%|██████    | 80/131 [00:10<00:05,  9.30it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  63%|██████▎   | 82/131 [00:10<00:05,  9.48it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  64%|██████▍   | 84/131 [00:10<00:04,  9.60it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  65%|██████▍   | 85/131 [00:10<00:04,  9.40it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  66%|██████▌   | 86/131 [00:10<00:04,  9.45it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  66%|██████▋   | 87/131 [00:10<00:04,  9.47it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  67%|██████▋   | 88/131 [00:10<00:04,  9.00it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  68%|██████▊   | 89/131 [00:11<00:04,  8.91it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  69%|██████▉   | 91/131 [00:11<00:04,  9.24it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  70%|███████   | 92/131 [00:11<00:04,  9.02it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  71%|███████   | 93/131 [00:11<00:04,  8.78it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  72%|███████▏  | 94/131 [00:11<00:04,  8.81it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  73%|███████▎  | 95/131 [00:11<00:04,  8.81it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  73%|███████▎  | 96/131 [00:12<00:12,  2.79it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  74%|███████▍  | 97/131 [00:12<00:09,  3.47it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  75%|███████▍  | 98/131 [00:12<00:07,  4.28it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  76%|███████▌  | 99/131 [00:13<00:06,  5.14it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  76%|███████▋  | 100/131 [00:13<00:05,  5.89it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  77%|███████▋  | 101/131 [00:13<00:04,  6.26it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  78%|███████▊  | 102/131 [00:13<00:04,  6.91it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  79%|███████▊  | 103/131 [00:13<00:03,  7.43it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  79%|███████▉  | 104/131 [00:13<00:03,  7.97it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  80%|████████  | 105/131 [00:13<00:03,  8.44it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  81%|████████  | 106/131 [00:13<00:02,  8.39it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  82%|████████▏ | 107/131 [00:13<00:02,  8.78it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  82%|████████▏ | 108/131 [00:14<00:02,  8.83it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  83%|████████▎ | 109/131 [00:14<00:02,  8.69it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  84%|████████▍ | 110/131 [00:14<00:02,  8.94it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  85%|████████▍ | 111/131 [00:14<00:02,  9.08it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  85%|████████▌ | 112/131 [00:14<00:02,  9.26it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  87%|████████▋ | 114/131 [00:14<00:01,  9.36it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  88%|████████▊ | 115/131 [00:14<00:01,  9.32it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  89%|████████▊ | 116/131 [00:14<00:01,  9.12it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  89%|████████▉ | 117/131 [00:15<00:01,  9.24it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  90%|█████████ | 118/131 [00:15<00:01,  9.30it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  91%|█████████ | 119/131 [00:15<00:01,  9.09it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  92%|█████████▏| 120/131 [00:15<00:01,  9.14it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  92%|█████████▏| 121/131 [00:15<00:01,  8.99it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  93%|█████████▎| 122/131 [00:15<00:00,  9.06it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  94%|█████████▍| 123/131 [00:15<00:00,  9.29it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  95%|█████████▍| 124/131 [00:15<00:00,  9.35it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  95%|█████████▌| 125/131 [00:15<00:00,  9.34it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  96%|█████████▌| 126/131 [00:16<00:00,  9.34it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  97%|█████████▋| 127/131 [00:16<00:00,  8.94it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  98%|█████████▊| 129/131 [00:16<00:00,  9.63it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  99%|█████████▉| 130/131 [00:16<00:00,  9.39it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events: 100%|██████████| 131/131 [00:16<00:00,  7.91it/s]

# %%
print(events_df.shape)
print(events_df[["match_id", "season", "home_team", "away_team"]].drop_duplicates().head())
# Out:
# (443304, 122)
#        match_id     season                   home_team                away_team
# 0       3775648  2020/2021                 Aston Villa              Arsenal WFC
# 3811    3775609  2020/2021                 Arsenal WFC      West Ham United LFC
# 7392    3775633  2020/2021                 Aston Villa  Tottenham Hotspur Women
# 10742   3775570  2020/2021  Brighton & Hove Albion WFC              Everton LFC
# 14444   3775581  2020/2021                 Chelsea FCW              Aston Villa

# %%
# Clean events column list
event_columns = ['id', 
                'index', 
                'location', 
                'match_id',
                'season',
                'competition',
                'match_date',
                'home_team',
                'away_team',
                'team', 
                'interception_outcome', 
                'minute', 
                'second',
                'pass_angle', 
                'pass_body_part', 
                'pass_cross', 
                'pass_deflected', 
                'pass_end_location', 
                'pass_goal_assist', 
                'pass_height', 
                'pass_length',
                'pass_outcome',
                'pass_recipient',
                'pass_recipient_id',
                'pass_type',
                'play_pattern',
                'player',
                'player_id', 
                'position',
                'possession_team',
                'possession_team_id',
                'related_events',
                'type',
                'under_pressure'
                ]

# %%
events_clean = events_df[event_columns]

# %%
# select rows where play_pattern is exactly 'From Throw In' and keep original events_df index
throws = events_clean[events_clean['play_pattern'] == 'From Throw In'].copy()
throws['event_idx'] = throws.index  # preserve original events_df index for lookup

# %%
# Provide a robust helper to convert an event's minute/second to absolute seconds
def _event_seconds(ev_row):
    """Return seconds from start of match for an event row (safe to missing values).
    ev_row is typically a pandas Series representing an events_df row.
    """
    # support dict-like or Series-like access
    if hasattr(ev_row, 'get'):
        minute = ev_row.get('minute', 0)
        second = ev_row.get('second', 0)
    else:
        minute = ev_row['minute'] if 'minute' in ev_row else 0
        second = ev_row['second'] if 'second' in ev_row else 0
    try:
        m = int(minute) if minute is not None else 0
    except Exception:
        m = 0
    try:
        s = int(second) if second is not None else 0
    except Exception:
        s = 0
    return m * 60 + s

# quick test (optional): uncomment to run a small check when executing this cell
# sample = {'minute': 12, 'second': 34}
# print(_event_seconds(sample))  # -> 754

# %%
# Build next_actions up to 3 actions (if not already present) and compute throw-level possession metrics
rows = []
for _, throw in throws.iterrows():
    mid = throw['match_id']
    throw_idx = throw['event_idx']
    throw_team = throw.get('team') if isinstance(throw.get('team'), dict) else throw.get('team')
    throw_name = throw_team.get('name') if isinstance(throw_team, dict) else throw_team
    throw_secs = throw.get('throw_seconds', None)
    later = events_df[(events_df['match_id'] == mid) & (events_df.index > throw_idx)].sort_index().head(3)
    for action_number, (_, act) in enumerate(later.iterrows(), start=1):
        action_team_obj = act.get('team')
        action_team = action_team_obj.get('name') if isinstance(action_team_obj, dict) else action_team_obj
        is_pass = isinstance(act.get('pass'), dict)
        pass_success = None
        if is_pass:
            p = act.get('pass')
            pass_success = ('outcome' not in p) if isinstance(p, dict) else None
        is_shot = isinstance(act.get('shot'), dict)
        is_goal = False
        if is_shot:
            s = act.get('shot')
            out = s.get('outcome') if isinstance(s, dict) else None
            if isinstance(out, dict):
                is_goal = (out.get('name') == 'Goal')
        action_secs = _event_seconds(act)
        time_from_throw = pd.NA
        try:
            if (throw_secs is not None) and (action_secs is not None):
                time_from_throw = action_secs - throw_secs
        except Exception:
            time_from_throw = pd.NA
        same_team = (action_team == throw_name)
        rows.append({
            'throw_event_idx': throw_idx,
            'match_id': mid,
            'throw_team': throw_name,
            'action_number': action_number,
            'action_index': act.name,
            'action_type': (act.get('type').get('name') if isinstance(act.get('type'), dict) else act.get('type')),
            'action_team': action_team,
            'action_seconds': action_secs,
            'time_from_throw': time_from_throw,
            'same_team_as_throw': same_team,
            'is_pass': bool(is_pass),
            'pass_success': pass_success,
            'is_shot': bool(is_shot),
            'is_goal': bool(is_goal)
        })

# %%
next_actions = pd.DataFrame(rows)

# %%
# Aggregate per throw_event_idx (i.e. per throw-in) to determine possession retention and other signals
def agg_throw(group):
    # group is rows for one throw-in, actions ordered by action_number
    group = group.sort_values('action_number')
    n_actions = len(group)
    # possession retained flags for first 1/2/3 actions (only True if those actions exist and are same team)
    retained1 = bool(group[group['action_number'] == 1]['same_team_as_throw'].all()) if n_actions >= 1 else pd.NA
    retained2 = bool(group[group['action_number'] <= 2]['same_team_as_throw'].all()) if n_actions >= 2 else pd.NA
    retained3 = bool(group[group['action_number'] <= 3]['same_team_as_throw'].all()) if n_actions >= 3 else pd.NA
    # where possession first lost (action_number) or NA if never lost in observed actions
    lost_actions = group[group['same_team_as_throw'] == False]['action_number']
    possession_lost_at = int(lost_actions.iloc[0]) if not lost_actions.empty else pd.NA
    # any shot/goal by throw team within observed actions
    any_shot = any((group['is_shot']) & (group['action_team'] == group['throw_team'].iloc[0]))
    any_goal = any((group['is_goal']) & (group['action_team'] == group['throw_team'].iloc[0]))
    # time to first shot by throw team
    shot_times = group[(group['is_shot']) & (group['action_team'] == group['throw_team'].iloc[0])]['time_from_throw'].dropna()
    time_to_first_shot = float(shot_times.min()) if not shot_times.empty else pd.NA
    mean_time = float(group['time_from_throw'].dropna().mean()) if not group['time_from_throw'].dropna().empty else pd.NA
    return pd.Series({
        'n_actions_observed': n_actions,
        'possession_retained_1': retained1,
        'possession_retained_2': retained2,
        'possession_retained_3': retained3,
        'possession_lost_at': possession_lost_at,
        'any_shot_by_throw_team': any_shot,
        'any_goal_by_throw_team': any_goal,
        'time_to_first_shot': time_to_first_shot,
        'mean_time_from_throw': mean_time
    })

# %%
throw_sequences = next_actions.groupby('throw_event_idx').apply(agg_throw).reset_index()
# Out:
# <positron-console-cell-38>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
# join throw metadata (match_id, throw_team) from one action row if available or from throws df
meta = throws[['event_idx','match_id']].rename(columns={'event_idx':'throw_event_idx'})
throw_sequences = throw_sequences.merge(meta, on='throw_event_idx', how='left')
throw_sequences = throw_sequences.merge(throws[['event_idx','team']].rename(columns={'event_idx':'throw_event_idx','team':'throw_team_obj'}), on='throw_event_idx', how='left')
def _team_name(obj):
    try:
        return obj.get('name') if isinstance(obj, dict) else obj
    except Exception:
        return obj
throw_sequences['throw_team'] = throw_sequences['throw_team_obj'].apply(_team_name)
throw_sequences = throw_sequences.drop(columns=['throw_team_obj'])
# Out:
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[39], line 4
#
#       2 meta = throws[['event_idx','match_id']].rename(columns={'event_idx':'throw_event_idx'})
#
#       3 throw_sequences = throw_sequences.merge(meta, on='throw_event_idx', how='left')
#
# ----> 4 throw_sequences = throw_sequences.merge(throws[['event_idx','team']].rename(columns={'event_idx':'throw_event_idx','team':'throw_team_obj'}), on='throw_event_idx', how='left')
#
#       5 def _team_name(obj):
#
#       6     try:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#
#    4106     if is_iterator(key):
#
#    4107         key = list(key)
#
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#
#    4110 # take() does not accept boolean indexers
#
#    4111 if getattr(indexer, "dtype", None) == bool:
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#
#    6197 else:
#
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#
#    6202 keyarr = self.take(indexer)
#
#    6203 if isinstance(key, Index):
#
#    6204     # GH 42790 - Preserve name from an Index
#
#
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# -> 6252 raise KeyError(f"{not_found} not in index")
#
#
#
# KeyError: "['team'] not in index"

# %%
# Example evaluator function: tune thresholds and rules here
def evaluate_throw_in(seq_row, require_retained_actions: int = 3, allow_shot_success: bool = True):
    # success if possession retained for required actions OR a shot/goal by throw team occurs in the window
    retained_key = f'possession_retained_{require_retained_actions}'
    retained = seq_row.get(retained_key)
    if retained is True:
        return True
    if allow_shot_success and seq_row.get('any_shot_by_throw_team'):
        return True
    return False

# %%
throw_sequences['success_default'] = throw_sequences.apply(lambda r: evaluate_throw_in(r, require_retained_actions=3, allow_shot_success=True), axis=1)

# %%
# Show samples
print('Action-level (next_actions) sample:')
display(next_actions.head(20))
print('\nThrow-level sequences (possession & shot metrics):')
display(throw_sequences.head(20))

# You can now filter throw_sequences by success_default or tune evaluate_throw_in to your criteria.
