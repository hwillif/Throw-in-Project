# %% [markdown]
# # Group 1 Throw-In Project

# %%
 # %pip install tqdm
 # %pip install statsbombpy
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tqdm in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm) (0.4.6)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsbombpy in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.16.0)
# Requirement already satisfied: pandas in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsbombpy) (2.2.3)
# Requirement already satisfied: requests in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsbombpy) (2.32.3)
# Requirement already satisfied: requests-cache in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsbombpy) (1.2.1)
# Requirement already satisfied: inflect in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsbombpy) (7.5.0)
# Requirement already satisfied: joblib in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsbombpy) (1.5.0)
# Requirement already satisfied: more_itertools>=8.5.0 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from inflect->statsbombpy) (10.8.0)
# Requirement already satisfied: typeguard>=4.0.1 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from inflect->statsbombpy) (4.4.4)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from typeguard>=4.0.1->inflect->statsbombpy) (4.14.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas->statsbombpy) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from pandas->statsbombpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas->statsbombpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas->statsbombpy) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from python-dateutil>=2.8.2->pandas->statsbombpy) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->statsbombpy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->statsbombpy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->statsbombpy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->statsbombpy) (2025.1.31)
# Requirement already satisfied: attrs>=21.2 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests-cache->statsbombpy) (25.3.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests-cache->statsbombpy) (25.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\program files\positron\resources\app\extensions\positron-python\python_files\lib\ipykernel\py3 (from requests-cache->statsbombpy) (4.3.8)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\earni\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests-cache->statsbombpy) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from statsbombpy import sb

from typing import Optional, Iterable
from statsbombpy import sb
from tqdm.auto import tqdm

# %% [markdown]
# ### Import Womans Data

# %%
# 2020-21 Womens Super League (Prem for Females)

WomenSL = sb.matches(competition_id=37, season_id=90)
# Out:
# C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
# Clean WomenSL
WomenSL_Clean = WomenSL[['match_id', 'match_date', 'competition', 'season', 'home_team', 'away_team', 'competition_stage']]
WomenSL_Clean.head()
# Out:
#    match_id  match_date                        competition     season  \
# 0   3775648  2021-02-28  England - FA Women's Super League  2020/2021
# 1   3775609  2021-04-28  England - FA Women's Super League  2020/2021
# 2   3775633  2021-02-06  England - FA Women's Super League  2020/2021
# 3   3775570  2021-03-28  England - FA Women's Super League  2020/2021
# 4   3775581  2021-03-28  England - FA Women's Super League  2020/2021
#
#                     home_team                away_team competition_stage
# 0                 Aston Villa              Arsenal WFC    Regular Season
# 1                 Arsenal WFC      West Ham United LFC    Regular Season
# 2                 Aston Villa  Tottenham Hotspur Women    Regular Season
# 3  Brighton & Hove Albion WFC              Everton LFC    Regular Season
# 4                 Chelsea FCW              Aston Villa    Regular Season

# %%
# Function for Matches Left Join Events
## Looking though all the events and only keeping the ones that occured in matches present in WomenSL
def build_events_dataset(
    matches_df: pd.DataFrame,
    match_id_col: str = "match_id",
    save_csv: Optional[str] = None,
    keep_columns: Optional[Iterable[str]] = None,
    add_meta: bool = True,
    ) -> pd.DataFrame:

# Fetch events for all match_ids in `matches_df`, concatenate into one DataFrame,
# and (optionally) merge key match metadata columns.

# Parameters
# ----------
# matches_df : DataFrame containing at least `match_id`
# match_id_col : name of the match id column
# save_parquet : path to save a Parquet file (recommended)
# save_csv : path to save a CSV file
# keep_columns : iterable of event columns to keep (None = keep all)
# add_meta : merge match metadata columns (season, teams, date, week, competition)

# Returns
# -------
# DataFrame of all events with `match_id` and optional metadata.

    if match_id_col not in matches_df.columns:
        raise KeyError(f"`{match_id_col}` not in matches_df columns")


    meta_cols = [
    match_id_col,
    "season", "season_id", "season_name",
    "competition", "competition_id", "competition_name",
    "match_date", "match_week",
    "home_team", "away_team"
    ]
    meta = matches_df[[c for c in meta_cols if c in matches_df.columns]].drop_duplicates()

    all_frames = []
    failures = []

    mids = pd.unique(matches_df[match_id_col].astype("int64"))
    for mid in tqdm(mids, desc="Fetching events"):
        try:
            ev = sb.events(match_id=int(mid))
            ev[match_id_col] = int(mid)
            all_frames.append(ev)
        except Exception as e:
            failures.append((int(mid), str(e)))

    if not all_frames:
        raise RuntimeError("No events were loaded. Check your match_ids or environment.")

    events = pd.concat(all_frames, ignore_index=True)


    if keep_columns is not None:
        keep = list(set(keep_columns) | {match_id_col})
        events = events[[c for c in keep if c in events.columns]]


    if add_meta and not meta.empty:
        events = events.merge(meta, on=match_id_col, how="left")


    if save_csv:
        events.to_csv(save_csv, index=False)
        print(f"Saved events: {len(events):,} rows → {save_csv}")

    if failures:
        print(f"\n Skipped {len(failures)} matches due to errors (showing first 5):")
    for mid, msg in failures[:5]:
        print(f" match_id={mid}: {msg}")

    return events



events_df = build_events_dataset(
WomenSL_Clean,
keep_columns=None,
add_meta=True
)
# Out:
# Fetching events:   0%|          | 0/131 [00:00<?, ?it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   1%|          | 1/131 [00:00<01:02,  2.08it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   2%|▏         | 2/131 [00:00<00:54,  2.38it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   2%|▏         | 3/131 [00:01<00:54,  2.35it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   3%|▎         | 4/131 [00:01<00:54,  2.32it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   4%|▍         | 5/131 [00:02<00:54,  2.32it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   5%|▍         | 6/131 [00:02<00:53,  2.33it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   5%|▌         | 7/131 [00:03<00:54,  2.26it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   6%|▌         | 8/131 [00:03<00:56,  2.16it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   7%|▋         | 9/131 [00:04<00:58,  2.08it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   8%|▊         | 10/131 [00:04<00:56,  2.14it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   8%|▊         | 11/131 [00:04<00:54,  2.20it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:   9%|▉         | 12/131 [00:05<00:51,  2.31it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  10%|▉         | 13/131 [00:05<00:49,  2.39it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  11%|█         | 14/131 [00:06<00:51,  2.27it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  11%|█▏        | 15/131 [00:06<00:50,  2.31it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  12%|█▏        | 16/131 [00:07<00:50,  2.29it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  13%|█▎        | 17/131 [00:07<00:48,  2.36it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  14%|█▎        | 18/131 [00:07<00:46,  2.43it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  15%|█▍        | 19/131 [00:08<00:45,  2.47it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  15%|█▌        | 20/131 [00:08<00:50,  2.20it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  16%|█▌        | 21/131 [00:09<00:55,  1.99it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  17%|█▋        | 22/131 [00:09<00:53,  2.03it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  18%|█▊        | 23/131 [00:10<00:50,  2.15it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  18%|█▊        | 24/131 [00:10<00:48,  2.21it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  19%|█▉        | 25/131 [00:11<00:46,  2.29it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  20%|█▉        | 26/131 [00:11<00:47,  2.23it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:
/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  98%|█████████▊| 129/131 [01:01<00:00,  2.15it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events:  99%|█████████▉| 130/131 [01:01<00:00,  2.24it/s]C:\Users\Earni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Fetching events: 100%|██████████| 131/131 [01:02<00:00,  2.10it/s]

# %%
print(events_df.shape)
print(events_df[["match_id", "season", "home_team", "away_team"]].drop_duplicates().head())
# Out:
# (443304, 121)
#        match_id     season                   home_team  \
# 0       3775648  2020/2021                 Aston Villa
# 3811    3775609  2020/2021                 Arsenal WFC
# 7392    3775633  2020/2021                 Aston Villa
# 10742   3775570  2020/2021  Brighton & Hove Albion WFC
# 14444   3775581  2020/2021                 Chelsea FCW
#
#                      away_team
# 0                  Arsenal WFC
# 3811       West Ham United LFC
# 7392   Tottenham Hotspur Women
# 10742              Everton LFC
# 14444              Aston Villa

# %%
# select rows where play_pattern is exactly 'From Throw In' and keep original events_df index
throws = events_df[events_df['play_pattern'] == 'From Throw In'].copy()
throws['event_idx'] = throws.index  # preserve original events_df index for lookup

# %%
# Provide a robust helper to convert an event's minute/second to absolute seconds
def _event_seconds(ev_row):
    """Return seconds from start of match for an event row (safe to missing values).
    ev_row is typically a pandas Series representing an events_df row.
    """
    # support dict-like or Series-like access
    if hasattr(ev_row, 'get'):
        minute = ev_row.get('minute', 0)
        second = ev_row.get('second', 0)
    else:
        minute = ev_row['minute'] if 'minute' in ev_row else 0
        second = ev_row['second'] if 'second' in ev_row else 0
    try:
        m = int(minute) if minute is not None else 0
    except Exception:
        m = 0
    try:
        s = int(second) if second is not None else 0
    except Exception:
        s = 0
    return m * 60 + s

# quick test (optional): uncomment to run a small check when executing this cell
# sample = {'minute': 12, 'second': 34}
# print(_event_seconds(sample))  # -> 754

# %%
# Build next_actions up to 3 actions (if not already present) and compute throw-level possession metrics
rows = []
for _, throw in throws.iterrows():
    mid = throw['match_id']
    throw_idx = throw['event_idx']
    throw_team = throw.get('team') if isinstance(throw.get('team'), dict) else throw.get('team')
    throw_name = throw_team.get('name') if isinstance(throw_team, dict) else throw_team
    throw_secs = throw.get('throw_seconds', None)
    later = events_df[(events_df['match_id'] == mid) & (events_df.index > throw_idx)].sort_index().head(3)
    for action_number, (_, act) in enumerate(later.iterrows(), start=1):
        action_team_obj = act.get('team')
        action_team = action_team_obj.get('name') if isinstance(action_team_obj, dict) else action_team_obj
        is_pass = isinstance(act.get('pass'), dict)
        pass_success = None
        if is_pass:
            p = act.get('pass')
            pass_success = ('outcome' not in p) if isinstance(p, dict) else None
        is_shot = isinstance(act.get('shot'), dict)
        is_goal = False
        if is_shot:
            s = act.get('shot')
            out = s.get('outcome') if isinstance(s, dict) else None
            if isinstance(out, dict):
                is_goal = (out.get('name') == 'Goal')
        action_secs = _event_seconds(act)
        time_from_throw = pd.NA
        try:
            if (throw_secs is not None) and (action_secs is not None):
                time_from_throw = action_secs - throw_secs
        except Exception:
            time_from_throw = pd.NA
        same_team = (action_team == throw_name)
        rows.append({
            'throw_event_idx': throw_idx,
            'match_id': mid,
            'throw_team': throw_name,
            'action_number': action_number,
            'action_index': act.name,
            'action_type': (act.get('type').get('name') if isinstance(act.get('type'), dict) else act.get('type')),
            'action_team': action_team,
            'action_seconds': action_secs,
            'time_from_throw': time_from_throw,
            'same_team_as_throw': same_team,
            'is_pass': bool(is_pass),
            'pass_success': pass_success,
            'is_shot': bool(is_shot),
            'is_goal': bool(is_goal)
        })

# %%
next_actions = pd.DataFrame(rows)

# %%
# Aggregate per throw_event_idx (i.e. per throw-in) to determine possession retention and other signals
def agg_throw(group):
    # group is rows for one throw-in, actions ordered by action_number
    group = group.sort_values('action_number')
    n_actions = len(group)
    # possession retained flags for first 1/2/3 actions (only True if those actions exist and are same team)
    retained1 = bool(group[group['action_number'] == 1]['same_team_as_throw'].all()) if n_actions >= 1 else pd.NA
    retained2 = bool(group[group['action_number'] <= 2]['same_team_as_throw'].all()) if n_actions >= 2 else pd.NA
    retained3 = bool(group[group['action_number'] <= 3]['same_team_as_throw'].all()) if n_actions >= 3 else pd.NA
    # where possession first lost (action_number) or NA if never lost in observed actions
    lost_actions = group[group['same_team_as_throw'] == False]['action_number']
    possession_lost_at = int(lost_actions.iloc[0]) if not lost_actions.empty else pd.NA
    # any shot/goal by throw team within observed actions
    any_shot = any((group['is_shot']) & (group['action_team'] == group['throw_team'].iloc[0]))
    any_goal = any((group['is_goal']) & (group['action_team'] == group['throw_team'].iloc[0]))
    # time to first shot by throw team
    shot_times = group[(group['is_shot']) & (group['action_team'] == group['throw_team'].iloc[0])]['time_from_throw'].dropna()
    time_to_first_shot = float(shot_times.min()) if not shot_times.empty else pd.NA
    mean_time = float(group['time_from_throw'].dropna().mean()) if not group['time_from_throw'].dropna().empty else pd.NA
    return pd.Series({
        'n_actions_observed': n_actions,
        'possession_retained_1': retained1,
        'possession_retained_2': retained2,
        'possession_retained_3': retained3,
        'possession_lost_at': possession_lost_at,
        'any_shot_by_throw_team': any_shot,
        'any_goal_by_throw_team': any_goal,
        'time_to_first_shot': time_to_first_shot,
        'mean_time_from_throw': mean_time
    })

# %%
throw_sequences = next_actions.groupby('throw_event_idx').apply(agg_throw).reset_index()
# Out:
# <positron-console-cell-15>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
# join throw metadata (match_id, throw_team) from one action row if available or from throws df
meta = throws[['event_idx','match_id']].rename(columns={'event_idx':'throw_event_idx'})
throw_sequences = throw_sequences.merge(meta, on='throw_event_idx', how='left')
throw_sequences = throw_sequences.merge(throws[['event_idx','team']].rename(columns={'event_idx':'throw_event_idx','team':'throw_team_obj'}), on='throw_event_idx', how='left')
def _team_name(obj):
    try:
        return obj.get('name') if isinstance(obj, dict) else obj
    except Exception:
        return obj
throw_sequences['throw_team'] = throw_sequences['throw_team_obj'].apply(_team_name)
throw_sequences = throw_sequences.drop(columns=['throw_team_obj'])

# %%
# Example evaluator function: tune thresholds and rules here
def evaluate_throw_in(seq_row, require_retained_actions: int = 3, allow_shot_success: bool = True):
    # success if possession retained for required actions OR a shot/goal by throw team occurs in the window
    retained_key = f'possession_retained_{require_retained_actions}'
    retained = seq_row.get(retained_key)
    if retained is True:
        return True
    if allow_shot_success and seq_row.get('any_shot_by_throw_team'):
        return True
    return False

# %%
throw_sequences['success_default'] = throw_sequences.apply(lambda r: evaluate_throw_in(r, require_retained_actions=3, allow_shot_success=True), axis=1)

# %%
# Show samples
print('Action-level (next_actions) sample:')
display(next_actions.head(20))
print('\nThrow-level sequences (possession & shot metrics):')
display(throw_sequences.head(20))

# You can now filter throw_sequences by success_default or tune evaluate_throw_in to your criteria.
# Out:
# Action-level (next_actions) sample:
#     throw_event_idx  match_id   throw_team  action_number  action_index  \
# 0                47   3775648  Aston Villa              1            48
# 1                47   3775648  Aston Villa              2            49
# 2                47   3775648  Aston Villa              3            50
# 3                48   3775648  Aston Villa              1            49
# 4                48   3775648  Aston Villa              2            50
# 5                48   3775648  Aston Villa              3            51
# 6                49   3775648  Aston Villa              1            50
# 7                49   3775648  Aston Villa              2            51
# 8                49   3775648  Aston Villa              3            52
# 9                50   3775648  Aston Villa              1            51
# 10               50   3775648  Aston Villa              2            52
# 11               50   3775648  Aston Villa              3            53
# 12               59   3775648  Arsenal WFC              1            60
# 13               59   3775648  Arsenal WFC              2            61
# 14               59   3775648  Arsenal WFC              3            62
# 15               60   3775648  Arsenal WFC              1            61
# 16               60   3775648  Arsenal WFC              2            62
# 17               60   3775648  Arsenal WFC              3            63
# 18               61   3775648  Arsenal WFC              1            62
# 19               61   3775648  Arsenal WFC              2            63
#
#    action_type  action_team  action_seconds time_from_throw  \
# 0         Pass  Aston Villa             191            <NA>
# 1         Pass  Aston Villa             192            <NA>
# 2         Pass  Aston Villa             194            <NA>
# 3         Pass  Aston Villa             192            <NA>
# 4         Pass  Aston Villa             194            <NA>
# 5         Pass  Arsenal WFC             197            <NA>
# 6         Pass  Aston Villa             194            <NA>
# 7         Pass  Arsenal WFC             197            <NA>
# 8         Pass  Arsenal WFC             198            <NA>
# 9         Pass  Arsenal WFC             197            <NA>
# 10        Pass  Arsenal WFC             198            <NA>
# 11        Pass  Arsenal WFC             201            <NA>
# 12        Pass  Arsenal WFC             231            <NA>
# 13        Pass  Arsenal WFC             235            <NA>
# 14        Pass  Arsenal WFC             239            <NA>
# 15        Pass  Arsenal WFC             235            <NA>
# 16        Pass  Arsenal WFC             239            <NA>
# 17        Pass  Aston Villa             256            <NA>
# 18        Pass  Arsenal WFC             239            <NA>
# 19        Pass  Aston Villa             256            <NA>
#
#     same_team_as_throw  is_pass pass_success  is_shot  is_goal
# 0                 True    False         None    False    False
# 1                 True    False         None    False    False
# 2                 True    False         None    False    False
# 3                 True    False         None    False    False
# 4                 True    False         None    False    False
# 5                False    False         None    False    False
# 6                 True    False         None    False    False
# 7                False    False         None    False    False
# 8                False    False         None    False    False
# 9                False    False         None    False    False
# 10               False    False         None    False    False
# 11               False    False         None    False    False
# 12                True    False         None    False    False
# 13                True    False         None    False    False
# 14                True    False         None    False    False
# 15                True    False         None    False    False
# 16                True    False         None    False    False
# 17               False    False         None    False    False
# 18                True    False         None    False    False
# 19               False    False         None    False    False
# Throw-level sequences (possession & shot metrics):
#     throw_event_idx  n_actions_observed  possession_retained_1  \
# 0                47                   3                   True
# 1                48                   3                   True
# 2                49                   3                   True
# 3                50                   3                  False
# 4                59                   3                   True
# 5                60                   3                   True
# 6                61                   3                   True
# 7                62                   3                  False
# 8                63                   3                  False
# 9                64                   3                   True
# 10               65                   3                   True
# 11               66                   3                   True
# 12               67                   3                   True
# 13               68                   3                   True
# 14               69                   3                   True
# 15               70                   3                   True
# 16               71                   3                   True
# 17               72                   3                   True
# 18               73                   3                   True
# 19               74                   3                   True
#
#    possession_retained_2 possession_retained_3 possession_lost_at  \
# 0                   True                  True               <NA>
# 1                   True                 False                  3
# 2                  False                 False                  2
# 3                  False                 False                  1
# 4                   True                  True               <NA>
# 5                   True                 False                  3
# 6                  False                 False                  2
# 7                  False                 False                  1
# 8                  False                 False                  1
# 9                   True                  True               <NA>
# 10                  True                  True               <NA>
# 11                  True                  True               <NA>
# 12                  True                  True               <NA>
# 13                  True                  True               <NA>
# 14                  True                  True               <NA>
# 15                  True                  True               <NA>
# 16                  True                  True               <NA>
# 17                  True                  True               <NA>
# 18                  True                  True               <NA>
# 19                  True                  True               <NA>
#
#     any_shot_by_throw_team  any_goal_by_throw_team time_to_first_shot  \
# 0                    False                   False               <NA>
# 1                    False                   False               <NA>
# 2                    False                   False               <NA>
# 3                    False                   False               <NA>
# 4                    False                   False               <NA>
# 5                    False                   False               <NA>
# 6                    False                   False               <NA>
# 7                    False                   False               <NA>
# 8                    False                   False               <NA>
# 9                    False                   False               <NA>
# 10                   False                   False               <NA>
# 11                   False                   False               <NA>
# 12                   False                   False               <NA>
# 13                   False                   False               <NA>
# 14                   False                   False               <NA>
# 15                   False                   False               <NA>
# 16                   False                   False               <NA>
# 17                   False                   False               <NA>
# 18                   False                   False               <NA>
# 19                   False                   False               <NA>
#
#    mean_time_from_throw  match_id   throw_team  success_default
# 0                  <NA>   3775648  Aston Villa             True
# 1                  <NA>   3775648  Aston Villa            False
# 2                  <NA>   3775648  Aston Villa            False
# 3                  <NA>   3775648  Aston Villa            False
# 4                  <NA>   3775648  Arsenal WFC             True
# 5                  <NA>   3775648  Arsenal WFC            False
# 6                  <NA>   3775648  Arsenal WFC            False
# 7                  <NA>   3775648  Arsenal WFC            False
# 8                  <NA>   3775648  Aston Villa            False
# 9                  <NA>   3775648  Arsenal WFC             True
# 10                 <NA>   3775648  Arsenal WFC             True
# 11                 <NA>   3775648  Arsenal WFC             True
# 12                 <NA>   3775648  Arsenal WFC             True
# 13                 <NA>   3775648  Arsenal WFC             True
# 14                 <NA>   3775648  Arsenal WFC             True
# 15                 <NA>   3775648  Arsenal WFC             True
# 16                 <NA>   3775648  Arsenal WFC             True
# 17                 <NA>   3775648  Arsenal WFC             True
# 18                 <NA>   3775648  Arsenal WFC             True
# 19                 <NA>   3775648  Arsenal WFC             True
